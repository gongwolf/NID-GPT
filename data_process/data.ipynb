# %%
import numpy as np

data = np.load('/data/qgong/code/NID-GPT/data/buddy/X_num_test.npy', allow_pickle=True)
data[0]
# Out:
# array([1.37868480e+09, 1.47549342e+09, 7.50000000e-01, 4.90700000e+01])

# %%
data = np.load('/data/qgong/code/NID-GPT/data/buddy/X_cat_test.npy', allow_pickle=True)
data[0]
# Out:
# array(['1.0', 'Brown', '0', '7', '2'], dtype=object)

# %%
data = np.load('/data/qgong/code/NID-GPT/data/buddy/y_test.npy', allow_pickle=True)
data[0]
# Out:
# 0

# %%
import pandas as pd 
df = pd.read_csv('/data/qgong/code/NID-GPT/data/buddy/test.csv')

df[(df['height(cm)']==49.07)]
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 2481  ANSL_69563  2014-08-28 00:00:00  2016-09-18 16:30:00        1.0
# 4840  ANSL_65954  2017-02-17 00:00:00  2017-07-11 16:20:00        0.0
# 6157  ANSL_66085  2018-03-20 00:00:00  2018-10-23 17:32:00        0.0
# 6610  ANSL_67425  2014-10-11 00:00:00  2017-09-08 14:15:00        0.0
# 7486  ANSL_60174  2016-06-03 00:00:00  2016-08-13 12:36:00        2.0
# 7526  ANSL_57313  2017-09-30 00:00:00  2018-10-25 10:58:00        NaN
#
#          color_type  length(m)  height(cm)  X1  X2
# 2481          Black       0.32       49.07   0   7
# 4840         Torbie       0.42       49.07  16   9
# 6157    Brown Tabby       0.87       49.07   0   1
# 6610          Black       0.68       49.07   0   1
# 7486  Black Brindle       0.88       49.07  13   9
# 7526          White       0.86       49.07   7   1

# %%
df
# Out:
#           pet_id           issue_date         listing_date  condition  \
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00        0.0
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00        1.0
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00        1.0
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00        1.0
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00        1.0
# ...          ...                  ...                  ...        ...
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00        2.0
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00        0.0
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00        0.0
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00        NaN
# 8071  ANSL_69436  2016-02-02 00:00:00  2017-02-28 16:47:00        0.0
#
#         color_type  length(m)  height(cm)  X1  X2
# 0            Black       0.87       42.73   0   7
# ...

# %%
from ctgan import CTGAN
from ctgan import load_demo

data = load_demo()
CTGAN.fit
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
import os
current_directory = os.getcwd()
current_directory
# Out:
# '/data/qgong/code/NID-GPT/scripts'
