# %%
import numpy as np 

syn_x_feature = np.load('/data/qgong/code/NID-GPT/exp/cicddos2019_all/ddpm_tune_best/X_num_train.npy')
org_x_feature = np.load('/data/qgong/code/NID-GPT/exp/cicddos2019_all/ddpm_tune_best/X_num_train.npy')
x_feature[:5]
# Out:
# array([[1.73758364e-04, 3.10263724e-04, 0.00000000e+00, 1.20492698e-03,
#         0.00000000e+00, 1.36986301e-02, 2.06475833e-01, 1.45922920e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 9.62032440e-04, 7.52834559e-04, 5.02746477e-06,
#         7.00407021e-06, 8.95852813e-06, 0.00000000e+00, 3.96184738e-05,
#         1.08474677e-05, 6.78943332e-06, 8.54201127e-06, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 9.99998307e-01, 9.99962714e-01, 1.08834859e-03,
#         0.00000000e+00, 2.98913043e-01, 1.15911486e-02, 1.09345421e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.15712878e-01,
# ...
