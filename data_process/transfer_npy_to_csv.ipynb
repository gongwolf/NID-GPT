# %%
import numpy as np 
import pandas as pd 

X = np.load('/data/qgong/code/NID-GPT/exp/flnet_all/X_num_train.npy')
y = np.load('/data/qgong/code/NID-GPT/exp/flnet_all/y_train.npy')

# Convert to a DataFrame and merge
df = pd.DataFrame(X)
df['label'] = y

df.shape
# Out:
# (2032037, 77)

# %%
df.head()
# Out:
#               0         1         2         3         4         5         6  \
# 0  2.224453e-02  0.000001  0.000017  0.000011  0.000010  0.037675  0.030882
# 1  2.654169e-01  0.000001  0.000004  0.000002  0.000002  0.188515  0.114734
# 2  5.723609e-06  0.040408  0.052632  0.038462  0.025156  0.076426  0.027941
# 3  4.856146e-07  0.000934  0.028703  0.011444  0.026233  0.001076  0.002941
# 4  2.286952e-05  0.011683  0.029313  0.017857  0.007728  0.089343  0.055882
#
#           7         8         9  ...        67       68        69        70  \
# 0  0.003733  0.008866  0.259589  ...  0.000000  0.00398  0.047421  0.174308
# 1  0.174405  0.009218  1.000000  ...  0.000774  0.00000  0.536072  0.054242
# 2  0.097709  0.002739  1.000000  ...  0.091266  0.00000  0.778331  0.064875
# 3  0.000063  0.000170  0.000000  ...  0.000000  0.00000  0.000000  0.038865
# 4  0.093740  0.003085  1.000000  ...  0.039661  0.00000  0.647137  0.054242
#
# ...

# %%
df.to_csv('/data/qgong/data/FLNET/results/ddpm_synthetic_data_all.csv', index=False)
