# %%
from sdv.single_table import CTGANSynthesizer
from ctgan import load_demo

real_data = load_demo()

real_data
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10, cuda=True)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data
# Out:
#      age  workclass  fnlwgt     education  education-num      marital-status  \
# 0     29    Private    7070     Bachelors             12  Married-civ-spouse
# 1     29    Private   56302  Some-college             14  Married-civ-spouse
# 2     27    Private   33875       HS-grad              9  Married-civ-spouse
# 3     34    Private   17032     Bachelors              9  Married-civ-spouse
# 4     42    Private  147495       HS-grad             13           Separated
# ..   ...        ...     ...           ...            ...                 ...
# 995   26    Private  163597    Assoc-acdm             10  Married-civ-spouse
# 996   67          ?  102126     Bachelors             10       Never-married
# 997   38  State-gov   85772       HS-grad              6  Married-civ-spouse
# 998   34    Private  141175       1st-4th             11  Married-civ-spouse
# 999   34    Private   -2000          11th             10       Never-married
#
# ...

# %%
import pandas as pd 

df = pd.read_csv('/data/qgong/data/CICIDS2017/cicids_all_test_dataset.csv')
print(df['label'].head())

label_mapping = {'BENIGN': 0, 'Bot': 1, 'DDoS': 2, 'DoS GoldenEye': 3, 'DoS Hulk': 4, 
                 'DoS Slowhttptest': 5, 'DoS slowloris': 6, 'FTP-Patator': 7, 
                 'PortScan': 8, 'SSH-Patator': 9}

# Replace labels with numerical values
df['label'] = df['label'].map(label_mapping)
df.to_csv('/data/qgong/data/CICIDS2017/cicids_all_test_dataset_num_label.csv', index=False)
# Out:
# 0    BENIGN
# 1    BENIGN
# 2    BENIGN
# 3      DDoS
# 4    BENIGN
# Name: label, dtype: object

# %%
import pandas as pd 

df = pd.read_csv('/data/qgong/data/CICIDS2017/ctgan_synthetic_data_all.csv')
print(df.columns)
df.drop(columns=['Unnamed: 0'], inplace=True)
df.to_csv('/data/qgong/data/CICIDS2017/ctgan_synthetic_data_all.csv', index=False)
df.head()
# Out:
# Index(['Unnamed: 0', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
df = pd.read_csv('/data/qgong/data/CICIDS2017/ctgan_synthetic_data_all_v1.csv')
df.head()
# Out:
#    Unnamed: 0   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0           0        0.000943            0.000095                 0.000000
# 1           1        0.000908            0.000439                 0.000000
# 2           2        0.000709            0.000062                 0.000000
# 3           3        0.519220            0.000200                 0.000012
# 4           4        0.095614            0.000000                 0.000000
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                     0.000357                      0.000000
# 1                     0.000304                      0.000167
# 2                     0.000286                      0.000139
# 3                     0.000840                      0.000254
# 4                     0.000527                      0.000000
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# ...
